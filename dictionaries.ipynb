# %%
thisdict = {"brand" : "Ford", "model" : "Mustang", "year" : 1964 }
print(thisdict)
print(thisdict["brand"])
thisdict = {"brand" : "Ford", "model" : "Mustang", "year" : 1964, "year" : 2020}
print(thisdict)
print(len(thisdict))

print(type(thisdict))

newdictionary = dict(name = "Sherniyaz", age = 18, country = "Kazakhstan")
print(newdictionary)

x = newdictionary["country"]
print(x)
y = newdictionary.get("name")
print(y)
z = newdictionary.keys()
print(z)

car = {"brand" : "BMW", "model" : "M5", "year" : 2022}
x = car.keys()
print(x)
car["color"] = "black"
print(x)
x = car.values()
print(x)
car["year"] = 2020
print(x)
if "model" in car:
    print("Yes, 'model is one of the keys in my car dictionary")
car.update({"color" : "blue"})
print(car)
car["cost"] = "36800$"
print(car)
car.pop("color")
car.popitem()
del car["year"]
print(car)
for x in car:
    print(x) #keys
for x in car:
    print(car[x]) #values
for x in car.keys():
    print(x)
for x in car.values():
    print(x)
for x, y in car.items():
    print(x,y) #both key and values
thesamecar = car.copy()
print(thesamecar)
mycar = dict(car)
print(mycar)
#dictionaries in dictionaries
myfamily = {
    "child1" : {
        "name": "ABCD",
        "year" : 1991
}, "child2" : {
        "name" : "EFBK",
        "year" : 1994
}, "child3" : {
        "name" : "VKSL",
        "year" : 2006
}
}
print(myfamily)
child1 = {
    "name": "ABCD",
    "year" : 1991
}
child2 = {
    "name" : "EFBK",
    "year" : 1994
}
child3 = {
    "name" : "VKSL",
    "year" : 2006}
myfam2 = {
    "child1" : child1,
    "child2" : child2,
    "child3" : child3
}
print(myfam2)

print(myfam2["child2"]["name"])
for x, obj in myfam2.items():
    print(x)
    for y in obj:
        print(y + ':', obj[y])
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}
# Ford
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}
# 3
# <class 'dict'>
# {'name': 'Sherniyaz', 'age': 18, 'country': 'Kazakhstan'}
# Kazakhstan
# Sherniyaz
# dict_keys(['name', 'age', 'country'])
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])
# dict_values(['BMW', 'M5', 2022, 'black'])
# dict_values(['BMW', 'M5', 2020, 'black'])
# Yes, 'model is one of the keys in my car dictionary
# {'brand': 'BMW', 'model': 'M5', 'year': 2020, 'color': 'blue'}
# {'brand': 'BMW', 'model': 'M5', 'year': 2020, 'color': 'blue', 'cost': '36800$'}
# {'brand': 'BMW', 'model': 'M5'}
# brand
# model
# BMW
# M5
# brand
# model
# BMW
# M5
# brand BMW
# model M5
# {'brand': 'BMW', 'model': 'M5'}
# {'brand': 'BMW', 'model': 'M5'}
# {'child1': {'name': 'ABCD', 'year': 1991}, 'child2': {'name': 'EFBK', 'year': 1994}, 'child3': {'name': 'VKSL', 'year': 2006}}
# ...
